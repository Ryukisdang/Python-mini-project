# %%
import time
from datetime import date
from datetime import datetime
from playsound import playsound
# for playing note.mp3 file

# datetime object containing current date and time


# dd/mm/YY
#"%B %d, %Y" - # Textual month, day and year
#H:M:S-hours,minute,seconds in numerical standard format 
# "%m/%d/%y for showing in numerical format short format in numerical format
def add():
    while True:
        try:
            print("enter two number,press enter after entering a digit and then press enter again sir")
            print("my creator is stupid didnt gaved me much functionality")
            n1=int(input())
            n2=int(input())
            add=n1+n2
            print("The sum of two number you entered is ",add)
            
        except:
            print("Sorry sir string data type and int data type cant be concanted")
            
        finally:
            #chatbot()
            print("Hope you are happy")
            user_input=input("Sir Wanna try adding more number ? Yes or No: ")
            if user_input.lower()=="yes":
                continue
            if user_input.lower()=="no":
                return chatbot()


def chatbot():
    print("THIS IS AN SIMPLE CHAT BOT\n")
    print("\nWant to have a chatbot talking with you yes or no: ",end=" ")
    #functinionality of rui to be written

    while True:
        user_input=str(input("give response to my question human yes or no to proceed..interaction with rui.: "))
        
        if user_input.lower()=="no":
            print("rui: Bye sir it was fun helping you")
            playsound("C:\Users\91936\Desktop\Python-mini-project\chat bot brain\respone speech\bye sir.mp3")
            time.sleep(1.5)
            break
            
        if user_input.lower()=="yes":
            
            h_input=str(input("ask rui: "))
            if h_input.lower()=="what is your name?":
                print("rui: My name is rui the chatbot")
                h_input=str(input("ask rui: "))
                
            if h_input == "hi rui":
                playsound('C:\\Users\\91936\\Desktop\\Python-mini-project\\chat bot brain\\respone speech\\hi sir.mp3')
                time.sleep(0.6)
                print('rui: hi sir')
                h_input=str(input("ask rui: "))
                
            if h_input=="who is your creator":
                playsound('C:\\Users\\91936\\Desktop\\Python-mini-project\\chat bot brain\\respone speech\\creator.mp3')
                print("rui: Hage tassang is my creator sir!!")
                time.sleep(0.5)
                playsound('C:\\Users\\91936\\Desktop\\Python-mini-project\\chat bot brain\\respone speech\\anymore question.mp3')
                print("rui: is there any more question wanna ask sir?")
                time.sleep(0.6)
                h_input=str(input("ask rui: "))
            if h_input=="make me laugh":
                playsound('C:\\Users\\91936\\Desktop\\Python-mini-project\\chat bot brain\\respone speech\\rickroll.mp3')
                time.sleep(1)
                print("hope you are happy")
                h_input=str(input("ask rui: "))
            if h_input=="make me cry":
                playsound('C:\\Users\\91936\\Desktop\\Python-mini-project\\chat bot brain\\respone speech\\mama.mp3')
                time.sleep(1.5)
                print("hope you are sad")
                h_input=str(input("ask rui: "))
                
                
                
            if h_input=="what is current date":
                today = date.today()
                print("rui: Today's date:", today)
                d2 = today.strftime("%B %d, %Y")
                print("d2 =", d2)
                time.sleep(0.5)
                h_input=str(input("ask rui: "))
                
            if h_input=="what is current time":
                now = datetime.now()
                current_time = now.strftime("%H:%M:%S")
                print("Current Time =", current_time)
                h_input=str(input("ask rui: "))
                
            if h_input.lower()=="no":
                playsound('C:\\Users\\91936\\Desktop\\Python-mini-project\\chat bot brain\\respone speech\\mama.mp3')
                print("rui: Bye sir it was fun helping you")
                time.sleep(1.5)
                break
                
            if h_input=="can you help me add two number?":
                print("rui: Wait a sec sir let me look up")
                return add()
                
            if h_input.lower()=="exit":
                print("rui: you dont want more of me sir ?")
                h_input=str(input(""))
                if h_input.lower()=="i guess nope":
                    print("Okay sir thats your wish")
                    h_input=str(input(""))
                elif h_input.lower()=="exit pls rui":
                    break
                
                
                
        if user_input.lower()=="exit":
            break
            
        if user_input.lower()=="continue":
            continue
# Out:
#   Cell In[7], line 47
#     playsound("C:\Users\91936\Desktop\Python-mini-project\chat bot brain\respone speech\bye sir.mp3")
#                                                                                                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
if __name__=="__main__":
    chatbot()
# Out:
# THIS IS AN SIMPLE CHAT BOT
#
#
# Want to have a chatbot talking with you yes or no:  give response to my question human yes or no to proceed..interaction with rui.: yes
# ask rui: exit
# rui: you dont want more of me sir ?
# no
# give response to my question human yes or no to proceed..interaction with rui.: yes
# ask rui: hi rui
# rui: hi sir
# ask rui: hi rui
# give response to my question human yes or no to proceed..interaction with rui.: yes
# ask rui: hi rui
# rui: hi sir
# ask rui: make me laugh
# hope you are happy
# ask rui: exit
# rui: you dont want more of me sir ?
# yes
# give response to my question human yes or no to proceed..interaction with rui.: yes
# ask rui: exit
# rui: you dont want more of me sir ?
# yes
# give response to my question human yes or no to proceed..interaction with rui.: no
# rui: Bye sir it was fun helping you
